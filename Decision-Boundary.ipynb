# %% [markdown]
# Perceptron learning rule / perceptron trick - works only for linearly separable data

# %%
from sklearn.datasets import make_regression 
import matplotlib.pyplot as plt 
import numpy as np 
from sklearn.model_selection import cross_val_score

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
class GDregressor:
    def __init__(self,learning_rate,epochs):
        self.m= 28.12597332 
        self.b= -120
        self.lr = learning_rate 
        self.epochs=epochs 

    def fit(self,X,y):
        for i in range(self.epochs):
              loss_slope_b = - 2 * np.sum(y - self.m * X.ravel() - self.b)
              loss_slope_m = - 2 * np.sum(y - self.m * X.ravel() - self.b) * X.ravel()
              self.b = self.b - (self.lr * loss_slope_b)
              self.m = self.m - (self.lr * loss_slope_m)
              print(f"m = {self.m}, b ={self.b}")
            
      

    def predict(self,X):
        return self.m * X + self.b

# %%
gd = GDregressor(0.001, 50)
gd.fit(X_train,y_train)
# Out:
# m = 28.12597332, b =-101.16336230822796
# m = 28.12597332, b =-85.34058664713945
# m = 28.12597332, b =-72.0494550918251
# m = 28.12597332, b =-60.88490458536104
# m = 28.12597332, b =-51.50668215993123
# m = 28.12597332, b =-43.62897532257019
# m = 28.12597332, b =-37.01170157918692
# m = 28.12597332, b =-31.45319163474497
# m = 28.12597332, b =-26.784043281413734
# m = 28.12597332, b =-22.861958664615496
# m = 28.12597332, b =-19.567407586504977
# m = 28.12597332, b =-16.79998468089214
# m = 28.12597332, b =-14.475349440177357
# m = 28.12597332, b =-12.52265583797694
# m = 28.12597332, b =-10.882393212128589
# m = 28.12597332, b =-9.504572606415975
# m = 28.12597332, b =-8.347203297617378
# m = 28.12597332, b =-7.375013078226558
# m = 28.12597332, b =-6.558373293938268
# m = 28.12597332, b =-5.872395875136105
# m = 28.12597332, b =-5.296174843342287
# m = 28.12597332, b =-4.812149176635481
# m = 28.12597332, b =-4.405567616601764
# m = 28.12597332, b =-4.064039106173441
# m = 28.12597332, b =-3.77715515741365
# m = 28.12597332, b =-3.5361726404554257
# m = 28.12597332, b =-3.333747326210517
# m = 28.12597332, b =-3.163710062244794
# m = 28.12597332, b =-3.0208787605135865
# m = 28.12597332, b =-2.900900467059372
# m = 28.12597332, b =-2.800118700557832
# m = 28.12597332, b =-2.7154620166965384
# m = 28.12597332, b =-2.644350402253052
# m = 28.12597332, b =-2.5846166461205233
# m = 28.12597332, b =-2.534440290969199
# m = 28.12597332, b =-2.4922921526420865
# m = 28.12597332, b =-2.456887716447312
# m = 28.12597332, b =-2.427147990043702
# m = 28.12597332, b =-2.402166619864669
# m = 28.12597332, b =-2.3811822689142814
# m = 28.12597332, b =-2.363555414115956
# m = 28.12597332, b =-2.3487488560853627
# m = 28.12597332, b =-2.3363113473396644
# m = 28.12597332, b =-2.3258638399932776
# m = 28.12597332, b =-2.3170879338223127
# m = 28.12597332, b =-2.309716172638702
# m = 28.12597332, b =-2.3035238932444693
# m = 28.12597332, b =-2.298322378553314
# m = 28.12597332, b =-2.293953106212743
# m = 28.12597332, b =-2.290282917446664
