# %% [markdown]
# why deep learning -
# 1. Feature Engeneering
# 2. If we increase dataset performance gets better
# 3. Complex patterns
#
# Problems with deep learning -
# 1. Too many parameters to many computation
# 2.
